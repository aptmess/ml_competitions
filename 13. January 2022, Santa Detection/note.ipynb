# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/santa/santa/
# Out:
# /content/drive/MyDrive/santa/santa

# %%
# !pip install -r requirements.txt

# %%
cd /content/drive/MyDrive/santa/santa/
# Out:
# /content/drive/MyDrive/santa/santa

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.1.2.30

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

sys.path.append('.')

from train import train_model

# %%
results = {
    'model_1': {'1.jpg': 1, '2.jpg': 2, '3.jpg': 0},
    'model_2': {'1.jpg': 2, '2.jpg': 0, '3.jpg': 0},
    'model_3': {'1.jpg': 0, '2.jpg': 0, '3.jpg': 1},
    'model_4': {'1.jpg': 1, '2.jpg': 0, '3.jpg': 1},
    'model_5': {'1.jpg': 2, '2.jpg': 0, '3.jpg': 1},
}

# %%
import pandas as pd
data = pd.DataFrame(results)

# %%
data
# Out:
#        model_1  model_2  model_3  model_4  model_5
# 1.jpg        1        2        0        1        2
# 2.jpg        2        0        0        0        0
# 3.jpg        0        0        1        1        1

# %%
data.mode?

# %%
data.median(axis=1).astype(int)
# Out:
# 1.jpg    1
# 2.jpg    0
# 3.jpg    1
# dtype: int64

# %%
# Out:
#    index  0
# 0  1.jpg  1
# 1  2.jpg  0
# 2  3.jpg  1

# %%
data = data.mode(axis=1)[0].astype(int).to_frame().reset_index()
data.columns = ['image_name', 'class_id']

# %%
data
# Out:
#   image_name  class_id
# 0      1.jpg         1
# 1      2.jpg         0
# 2      3.jpg         1

# %%
train_model()
# Out:
# {"asctime": "2022-01-05 17:36:26", "name": "train", "filename": "train.py", "levelname": "INFO", "message": "device: cuda"}
# {"asctime": "2022-01-05 17:36:26", "name": "train", "filename": "train.py", "levelname": "INFO", "message": "Loading model..."}
# {"asctime": "2022-01-05 17:36:26", "name": "train", "filename": "train.py", "levelname": "INFO", "message": "Starting fold 1 / 3"}
# {"asctime": "2022-01-05 17:36:26", "name": "santa_barbara.utils", "filename": "utils.py", "levelname": "INFO", "message": "Loading model efficientnet_b7"}
# {"asctime": "2022-01-05 17:36:28", "name": "train", "filename": "train.py", "levelname": "INFO", "message": "Done."}
# {"asctime": "2022-01-05 17:36:28", "name": "santa_barbara.train", "filename": "train.py", "levelname": "INFO", "message": "0.001"}
# {"asctime": "2022-01-05 17:36:28", "name": "santa_barbara.train", "filename": "train.py", "levelname": "INFO", "message": "Opt: SGD"}
# Epochs:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
так ч
