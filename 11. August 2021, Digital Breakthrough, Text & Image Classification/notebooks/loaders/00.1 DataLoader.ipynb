# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/digital_breakthrough/task_3
# Out:
# /content/drive/MyDrive/digital_breakthrough/task_3

# %%
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm
sys.path.append('.')
from definitions import ROOT_DIR

# %%
DATA_PATH = ROOT_DIR / 'data'
TRAIN_IMAGES = DATA_PATH / 'images'
DOWNLOADED_TRAIN_IMAGES = DATA_PATH / 'downloaded_images'

# %%
train = pd.read_csv(DATA_PATH / 'train.csv')
test = pd.read_csv(DATA_PATH / 'test.csv')
train_url_only = pd.read_csv(DATA_PATH / 'train_url_only.csv')
sample_submission = pd.read_csv(DATA_PATH / 'sample_submission.csv')

# %%
from os import listdir
train_images = listdir(TRAIN_IMAGES)
guid_train_images = [f.split('.')[0] for f in train_images]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-38bafdb37188> in <module>()
# ----> 1 train_images = listdir(TRAIN_IMAGES)
#       2 guid_train_images = [f.split('.')[0] for f in train_images]
#
# NameError: name 'listdir' is not defined

# %%
dummy = test[test.guid.isin(guid_train_images)]
test_only_description = test[~(test.guid.isin(guid_train_images))]
test_only_images = dummy[dummy.description.isna()]
test_images_and_description = dummy[~(dummy.description.isna())]

# %%
print('without image or description:', len(labels_without_images[labels_without_images.description.isna()]))
print('only description:', test_only_description.shape[0])
print('only images:', test_only_images.shape[0])
print('images and description:', test_images_and_description.shape[0])
# Out:
# without image or description: 0
# only description: 78
# only images: 547
# images and description: 598

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = listdir(DOWNLOADED_TRAIN_IMAGES)
donwload_url = train_url_only[~(train_url_only.url.isna())]

# %%
ls
# Out:
# '12. Data Fusion Solutions'/   log_config.yml  '__pycache__ (1)'/
#  config.yml                    models/          requirements.txt
#  data/                         notebooks/       src/
#  definitions.py                __pycache__/     sub/

# %%
images_with_url = donwload_url[donwload_url.guid.isin(guid_donwloaded_files)].reset_index(drop=True)
images_with_url.to_csv('./data/train_loaded_images.csv', index=False)

# %%
guid_donwloaded_files = [f.split('.')[0] for f in onlyfiles]

# %%
need_to_download = donwload_url[~(donwload_url.guid.isin(guid_donwloaded_files))].reset_index(drop=True)

# %%
need_to_download
# Out:
#                                       guid  ...                                                url
# 0     3a863b18-d97e-4e20-93a9-14bacb366cdb  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 1     369c04c1-1fbf-49e1-b991-bee14fdf58e4  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 2     5481c135-5ab2-4eb8-a6e9-551219e87044  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 3     d83a14b6-2851-4a87-bf4d-f62ab17b8ae4  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 4     6bc23cd3-74e8-44ea-b00a-3e0208539b16  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# ...                                    ...  ...                                                ...
# 4722  14b6a48d-e507-4ffa-9ab3-8ad40bbfe39b  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 4723  10a9b9e7-f892-4eb9-b71a-efb9b37091ef  ...  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# ...

# %%
len(need_to_download)
# Out:
# 4727

# %%
start = 0
end = 17500
step1 = need_to_download[start:end]

# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9673 sha256=76a593464f6a9f4d734d5f958c8cd7e6ba461662ff9ec25883bc4811b0e5e54a
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
import wget

# %%
a = []
import time
from tqdm import tqdm
for i, row in tqdm(step1.iterrows(), total=len(step1)):
    filename = row['guid']
    url = row['url']
    try:
        wget.download(row['url'], str(DOWNLOADED_TRAIN_IMAGES / f'{filename}.jpg'))
    except Exception as ex:
        a.append(filename)
        continue
# Out:
# 100%|██████████| 4727/4727 [49:31<00:00,  1.59it/s]
